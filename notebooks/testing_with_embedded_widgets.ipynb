# %%
import os
import matplotlib.pyplot as plt
# %matplotlib notebook
import matplotlib

from code.main_with_embedded import Main

# %%
print(f"Matplotlib version: {matplotlib.__version__}")
# Out:
# Matplotlib version: 3.8.0

# %%
data_file = "data/fitting_y2023_m11_d01_h10_mn12.h5"
assert os.path.exists(data_file)

# %% [markdown]
# ### load the data

# %%
o_strain_display = Main(working_dir = os.path.dirname(data_file))
o_strain_display.load(data_file)
# Out:
# <span style="font-size: 20px; color:blue">fitting_y2023_m11_d01_h10_mn12.h5 has been loaded !</span>

# %% [markdown]
# # Display all data

# %%
o_strain_display.process_data()
o_strain_display.display_data()
# Out:
# <img src="data:image/png;base64,..." width="400">
# interactive(children=(Dropdown(description='data_type', options=('d', 'strain', 'lambda'), value='d'), Dropdow…
